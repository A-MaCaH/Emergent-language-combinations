# %% [markdown]
# # Emergent generalization
# IMplementacipon de: https://github.com/jayelm/emergent-generalization.**git**

# %%
# 1. Instalar dependencias necesarias
# !pip install torch==1.8.1
# !pip install -r requirements.txt

# 2. Clonar el repositorio
# !git clone https://github.com/jayelm/emergent-generalization.git
# Out:
# ERROR: Could not find a version that satisfies the requirement torch==1.8.1 (from versions: 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0)
# ERROR: No matching distribution found for torch==1.8.1
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.7/53.7 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 44.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (pyproject.toml) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# ...

# %%
# !pip install hausdorff

# %%
# %cd /content/emergent-generalization
# Out:
# /content/emergent-generalization

# %%
# 3. Descargar y procesar los datos
# Birds dataset (CUB)
# !wget http://www.vision.caltech.edu/visipedia-data/CUB-200-2011/CUB_200_2011.tgz
# !mkdir -p data/cub
# !tar -xvzf CUB_200_2011.tgz -C data/cub
# !python data/save_cub_np.py

# ShapeWorld dataset
# !chmod +x data/download_shapeworld.sh
# !./data/download_shapeworld.sh
# Out:
# /content/emergent-generalization
# --2025-02-20 21:10:50--  http://www.vision.caltech.edu/visipedia-data/CUB-200-2011/CUB_200_2011.tgz
# Resolving www.vision.caltech.edu (www.vision.caltech.edu)... 185.199.111.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to www.vision.caltech.edu (www.vision.caltech.edu)|185.199.111.153|:80... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-20 21:10:50 ERROR 404: Not Found.
#
# tar (child): CUB_200_2011.tgz: Cannot open: No such file or directory
# tar (child): Error is not recoverable: exiting now
# tar: Child returned status 2
# tar: Error is not recoverable: exiting now
# Traceback (most recent call last):
#   File "/content/emergent-generalization/data/save_cub_np.py", line 25, in <module>
#     for bird_class in tqdm(os.listdir(args.cub_dir), desc="Classes"):
#                            ^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'cub/CUB_200_2011/images'
# ...

# %%
# !pip install numpy==1.24

# %%
# 4. Entrenar un modelo de ejemplo
# !python code/train.py --cuda --name test_experiment --dataset data/shapeworld
# Out:
# /content/emergent-generalization/code/util.py:30: UserWarning: Running experiments with unstaged changes.
#   warnings.warn("Running experiments with unstaged changes.")
# Traceback (most recent call last):
#   File "/content/emergent-generalization/code/train.py", line 468, in <module>
#     dataloaders = data.loader.load_dataloaders(args)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/emergent-generalization/code/data/loader.py", line 25, in load_dataloaders
#     datas = load(args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^
#   File "/content/emergent-generalization/code/data/loader.py", line 16, in load
#     return lf(args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/content/emergent-generalization/code/data/shapeworld.py", line 227, in load
#     other_data = load_other_data(
#                  ^^^^^^^^^^^^^^^^
#   File "/content/emergent-generalization/code/data/shapeworld.py", line 158, in load_other_data
# ...
