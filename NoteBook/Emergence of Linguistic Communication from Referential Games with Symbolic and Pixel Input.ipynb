# %% [markdown]
# # Emergence of Linguistic Communication from Referential Games with Symbolic and Pixel Input
#
# https://github.com/nickleomartin/emergent_comm_rl?tab=readme-ov-file

# %%
# !git clone https://github.com/nickleomartin/emergent_comm_rl.git
# Out:
# Cloning into 'emergent_comm_rl'...
# remote: Enumerating objects: 361, done.
# remote: Total 361 (delta 0), reused 0 (delta 0), pack-reused 361 (from 1)
# Receiving objects: 100% (361/361), 151.05 KiB | 836.00 KiB/s, done.
# Resolving deltas: 100% (233/233), done.
# Filtering content: 100% (16/16), 201.33 KiB | 123.00 KiB/s, done.

# %%
# %cd emergent_comm_rl
# Out:
# /content/emergent_comm_rl

# %%
# !pip install torch==1.8.1
# !pip install -r requirements.txt
# Out:
# ERROR: Could not find a version that satisfies the requirement torch==1.8.1 (from versions: 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0)
# ERROR: No matching distribution found for torch==1.8.1
# ...
#   Using cached absl-py-0.2.2.tar.gz (82 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip install keras
# !pip install np_utils

# %%
# !python -m experiments.random_agent_experiments
# Out:
# Using TensorFlow backend.
# 2025-02-20 23:07:37.648745: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740092857.674279    3942 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740092857.681768    3942 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-20 23:07:37.705570: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
python -m experiments.dense_visa_agents_experiments
# Out:
#   File "<ipython-input-29-0a0b5a539115>", line 1
#     python -m experiments.dense_visa_agents_experiments
#               ^
# SyntaxError: invalid syntax
